# %%
a = 1
b = 2
c = 3
d = 4

# %%
a + b, a - b, a * c
# Out:
# (3, -1, 3)

# %%
print(a + b)
print(a + b, a - b, a * c)
# Out:
# 3
# 3 -1 3

# %%
print(a * b)
print(d / b)
print(d % c)
# Out:
# 2
# 2.0
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = input()
# Out:
# 10

# %%
type(a)
# Out:
# str

# %%
a = float(input())
# Out:
# 10

# %%
type(a)
# Out:
# float

# %%
a = int(input())
# Out:
# 10

# %%
type(a)
# Out:
# int

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
10 < 15
# Out:
# True

# %%
10 <= 15
# Out:
# True

# %%
10 > 61
# Out:
# False

# %%
print(bool(1))
# Out:
# True

# %%
print(bool(0))
# Out:
# False

# %%
print(bool("안녕"))
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
1 == 0
# Out:
# False

# %%
a != b
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
not 1 == 1 # 같이 않다
# Out:
# False

# %%
1 == 1 and 1 == 2
# Out:
# False

# %%
1 == 1 or 1 == 2
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
"Life is too short, You need python"
# Out:
# 'Life is too short, You need python'

# %%
"a"
# Out:
# 'a'

# %%
"123"
# Out:
# '123'

# %%
food = "Python's favorite food is perl"

# %%
type(food)
# Out:
# str

# %%
python = 'python'

# %%
a = 'python'
b = 2

# %%
a * b
# Out:
# 'pythonpython'

# %%
print("="*50)
print("My program")
print("="*50)
# Out:
# ==================================================
# My program
# ==================================================

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = "안녕하세요 지금은 인공지능 수업 시간입니다."

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A[0:5]
# Out:
# '안녕하세요'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A[-1]
# Out:
# '.'

# %%
A[-5:]
# Out:
# '간입니다.'

# %%
A[-11:-10]
# Out:
# '능'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(("이번시험의 성적으로 {}점을 맞았습니다.").format(100))
# Out:
# 이번시험의 성적으로 100점을 맞았습니다.

# %%
print(f"이번시험의 성적으로 {100}점을 맞았습니다.")
# Out:
# 이번시험의 성적으로 100점을 맞았습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = "I am a "
B = "boy"

# %%
A + B
# Out:
# 'I am a boy'

# %%
A = "I am a {}"
B = "boy"

# %%
A.format(B)
# Out:
# 'I am a boy'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = 10
B = 20

# %%
print(f"{A}, {B}")
# Out:
# 10, 20

# %%
print("{}, {}".format(A, B))
# Out:
# 10, 20

# %%
"I am a {}".format(A)
# Out:
# 'I am a 10'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("{:.2f}, {:.3f}".format(3.1415, 3.1415))
# Out:
# 3.14, 3.142

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
url = "https://www.youtube.com/"
str = url.replace("https://", "")

# %%
str
# Out:
# 'www.youtube.com/'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = "독고영재, 50"
b = "김철수, 30"

# %%
a
# Out:
# '독고영재, 50'

# %% [markdown]
# # , 직전까지 독고영재 출력

# %%
a[:a.index(",")]
# Out:
# '독고영재'

# %% [markdown]
# # , 부터 전부 출력

# %%
a[a.index(","):]
# Out:
# ', 50'

# %%
b
# Out:
# '김철수, 30'

# %%
b[:b.index(",")]
# Out:
# '김철수'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
people = ["독고영재, 50", "김철수, 30"]

# %%
people[0]
# Out:
# '독고영재, 50'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = ["독고영재, 50", "김철수, 30"]

# %%
A[0][0:4]
# Out:
# '독고영재'

# %%
A[1][5:7]
# Out:
# '30'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A[0][:A[0].index(",")]
# Out:
# '독고영재'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = ["hi", 10, "80", "김철수", 50, 50.6]

# %%
a
# Out:
# ['hi', 10, '80', '김철수', 50, 50.6]

# %%
a.append(1)

# %%
a
# Out:
# ['hi', 10, '80', '김철수', 50, 50.6, 1]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a.pop(1)
# Out:
# 10

# %%
a
# Out:
# ['hi', '80', '김철수', 50, 50.6, 1]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = {1:"김철수", 20:"박영희"}

# %%
A[1]
# Out:
# '김철수'

# %%
A[20]
# Out:
# '박영희'

# %%
A.get(1)
# Out:
# '김철수'

# %%
A.get(20)
# Out:
# '박영희'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = {"1-A":"김철수", "20-B":"박영희"}

# %%
A["1-A"]
# Out:
# '김철수'

# %%
A["20-B"]
# Out:
# '박영희'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A
# Out:
# {'1-A': '김철수', '20-B': '박영희'}

# %%
A["2-A"] = "영희"

# %%
A
# Out:
# {'1-A': '김철수', '20-B': '박영희', '2-A': '영희'}

# %%
del A["2-A"]

# %%
A
# Out:
# {'1-A': '김철수', '20-B': '박영희'}
